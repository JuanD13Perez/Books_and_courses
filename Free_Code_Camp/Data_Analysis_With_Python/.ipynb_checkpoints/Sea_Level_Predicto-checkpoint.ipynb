# %% [markdown]
# # Sea Level Predictor
# ### For an explanation of this project please visit [FCC](https://www.freecodecamp.org/learn/data-analysis-with-python/data-analysis-with-python-projects/sea-level-predictor)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

def draw_plot():
    # Read data from file
    df = pd.read_csv('epa-sea-level.csv')


    # Create scatter plot
    plt.scatter(data = df, x = 'Year', y='CSIRO Adjusted Sea Level')

    # Create first line of best fit
    x = pd.Series(range(1880,2051,1))
    line = linregress(x = df['Year'], y = df['CSIRO Adjusted Sea Level'])
    plt.plot(x, (line.slope)*x + line.intercept , color ='yellow', linewidth=2)


    # Create second line of best fit
    x2= pd.Series(range(2000,2051,1))
    line_2000 = linregress(x = df['Year'][df['Year'] >= 2000], y = df['CSIRO Adjusted Sea Level'][df['Year'] >= 2000])
    plt.plot(x2, (line_2000.slope)*x2 + line_2000.intercept , color ='red', linewidth=2)

    # Add labels and title
    plt.title('Rise in Sea Level')
    plt.xlabel('Year')
    plt.ylabel('Sea Level (inches)')
    plt.xlim(1870, 2060)

    
    # Save plot and return data for testing (DO NOT MODIFY)
    plt.savefig('sea_level_plot.png')
    return plt.gca()

# %%
draw_plot()
# Out:
# <AxesSubplot:title={'center':'Rise in Sea Level'}, xlabel='Year', ylabel='Sea Level (inches)'>

# %% [markdown]
# ## Results
# #### Below there is an image that show that all the tests were succesfully cmpleted.

# %% [markdown]
# ![Image 5](Results_5.png)
